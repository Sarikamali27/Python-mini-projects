# %% [markdown]
# 1.Business scenario

# %%
# Data Capture: (Employee1)
print("\n -----Employee1 Details----- \n")
name = input("Enter employee1: ")
base_pay = float(input("Enter base pay: "))
HRA = 20
DA = 10 
PF_Deduction = 5
# Arithmetic Engine:
HRA = (HRA / 100) * base_pay
DA = (DA /100)*base_pay
PF = (PF_Deduction/100)*base_pay
Total_gross = base_pay + HRA + DA
Net_pay = Total_gross - PF_Deduction
# Loginal Evaluation:
is_high_earner = Net_pay > 80000
is_mid_range = Net_pay >=40000 and Net_pay <=80000

print("\n -----Salary Details----- \n")
print("Employee1 name: ",name)
print("Base pay: ",base_pay)
print("House rent Allowance(HRA%): ",HRA)
print("Dearness Allowance(DA%): ",DA)
print("Provident Fund(PF%): ",PF_Deduction)
print("Total gross: ",Total_gross)
print("Net pay: ",Net_pay)
print("High_earner: ",is_high_earner)
print("Mid_earner: ",is_mid_range)

#------------------------------------------------------------------------------------------

# Data Capture: (Employee2)
print("\n -----Employee2 Details----- \n")
name = input("Enter employee2: ")
base_pay = float(input("Enter base pay: "))
HRA = 30
DA = 20 
PF_Deduction = 10
# Arithmetic Engine:
HRA = (HRA / 100) * base_pay
DA = (DA /100)*base_pay
PF = (PF_Deduction/100)*base_pay
Total_gross = base_pay + HRA + DA
Net_pay = Total_gross - PF_Deduction
# Loginal Evaluation:
is_high_earner = Net_pay > 80000
is_mid_range = Net_pay >=40000 and Net_pay <=80000

print("\n -----Salary Details----- \n")
print("Employee2 name: ",name)
print("Base pay: ",base_pay)
print("House rent Allowance(HRA%): ",HRA)
print("Dearness Allowance(DA%): ",DA)
print("Provident Fund(PF%): ",PF_Deduction)
print("Total gross: ",Total_gross)
print("Net pay: ",Net_pay)
print("High_earner: ",is_high_earner)
print("Mid_earner: ",is_mid_range)

#----------------------------------------------------------------------------------------

# Data Capture: (Employee3)
print("\n -----Employee3 Details----- \n")
name = input("Enter employee3: ")
base_pay = float(input("Enter base pay: "))
HRA = 10
DA = 5 
PF_Deduction = 10
# Arithmetic Engine:
HRA = (HRA / 100) * base_pay
DA = (DA /100)*base_pay
PF = (PF_Deduction/100)*base_pay
Total_gross = base_pay + HRA + DA
Net_pay = Total_gross - PF_Deduction
# Loginal Evaluation:
is_high_earner = Net_pay > 80000
is_mid_range = Net_pay >=40000 and Net_pay <=80000

print("\n -----Salary Details----- \n")
print("Employee3 name: ",name)
print("Base pay: ",base_pay)
print("House rent Allowance(HRA%): ",HRA)
print("Dearness Allowance(DA%): ",DA)
print("Provident Fund(PF%): ",PF_Deduction)
print("Total gross: ",Total_gross)
print("Net pay: ",Net_pay)
print("High_earner: ",is_high_earner)
print("Mid_earner: ",is_mid_range)

#----------------------------------------------------------------------------------------------------------

# Data Capture: (Employee4)
print("\n -----Employee4 Details----- \n")
name = input("Enter employee4: ")
base_pay = float(input("Enter base pay: "))
HRA = 40
DA = 10 
PF_Deduction = 30
# Arithmetic Engine:
HRA = (HRA / 100) * base_pay
DA = (DA /100)*base_pay
PF = (PF_Deduction/100)*base_pay
Total_gross = base_pay + HRA + DA
Net_pay = Total_gross - PF_Deduction
# Loginal Evaluation:
is_high_earner = Net_pay > 80000
is_mid_range = Net_pay >=40000 and Net_pay <=80000

print("\n -----Salary Details----- \n")
print("Employee4 name: ",name)
print("Base pay: ",base_pay)
print("House rent Allowance(HRA%): ",HRA)
print("Dearness Allowance(DA%): ",DA)
print("Provident Fund(PF%): ",PF_Deduction)
print("Total gross: ",Total_gross)
print("Net pay: ",Net_pay)
print("High_earner: ",is_high_earner)
print("Mid_earner: ",is_mid_range)

#-----------------------------------------------------------------------------------------------------------------------

# Data Capture: (Employee5)
print("\n -----Employee5 Details----- \n")
name = input("Enter employee5: ")
base_pay = float(input("Enter base pay: "))
HRA = 10
DA = 20 
PF_Deduction = 30
# Arithmetic Engine:
HRA = (HRA / 100) * base_pay
DA = (DA /100)*base_pay
PF = (PF_Deduction/100)*base_pay
Total_gross = base_pay + HRA + DA
Net_pay = Total_gross - PF_Deduction
# Loginal Evaluation:
is_high_earner = Net_pay > 80000
is_mid_range = Net_pay >=40000 and Net_pay <=80000

print("\n -----Salary Details----- \n")
print("Employee5 name: ",name)
print("Base pay: ",base_pay)
print("House rent Allowance(HRA%): ",HRA)
print("Dearness Allowance(DA%): ",DA)
print("Provident Fund(PF%): ",PF_Deduction)
print("Total gross: ",Total_gross)
print("Net pay: ",Net_pay)
print("High_earner: ",is_high_earner)
print("Mid_earner: ",is_mid_range)

#------------------------------------------------------------------------------------------------------------------------------
# Out:
#  -----Employee1 Details-----
# Enter employee1:  karan
# Enter base pay:  50000
#  -----Salary Details-----
#
# Employee1 name:  karan
# Base pay:  50000.0
# House rent Allowance(HRA%):  10000.0
# Dearness Allowance(DA%):  5000.0
# Provident Fund(PF%):  5
# Total gross:  65000.0
# Net pay:  64995.0
# High_earner:  False
# Mid_earner:  True
#
#  -----Employee2 Details-----
# Enter employee2:  rohit
# Enter base pay:  40000
#  -----Salary Details-----
#
# Employee2 name:  rohit
# Base pay:  40000.0
# House rent Allowance(HRA%):  12000.0
# Dearness Allowance(DA%):  8000.0
# Provident Fund(PF%):  10
# Total gross:  60000.0
# Net pay:  59990.0
# High_earner:  False
# Mid_earner:  True
#
#  -----Employee3 Details-----
# Enter employee3:  yash
# Enter base pay:  67000
#  -----Salary Details-----
#
# Employee3 name:  yash
# Base pay:  67000.0
# House rent Allowance(HRA%):  6700.0
# Dearness Allowance(DA%):  3350.0
# Provident Fund(PF%):  10
# Total gross:  77050.0
# Net pay:  77040.0
# ...

# %% [markdown]
# Conclusion :- in these assignment,we calculate the total gross salary and net pay using the base pay,
#               HRA,DA,PF. and also calculate the HRA,DA,PF using the arithmetic operators.we find out the employee is high earner
#               or mid earner using the logical and comparison operators on basis of their salary.
